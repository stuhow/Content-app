# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://parkhoteltokyo.com"

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36",
    "Accept-Language": "en-GB,en;q=0.5",
    "Referer": "https://google.com",
    "DNT": "1"
}

# %%
response = requests.get(url, headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n<head>\n\t<meta charset="UTF-8">\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t<meta name="viewport" content="width=device-width, initial-scale=1, minimal-ui, user-scalable=no">\n\t<script no-loader>/* Added by mu-plugin gmaps_keys_api_client.php */var fb__website_gmap_api_key = "AIzaSyAp16-BNgTll5F3xOW6fuClAbjP0qe4pQo";</script>        <!-- DEdge Macaron plugin output ( macaron-utils.min.js ) -->\n        <script no-loader type=\'text/javascript\'>\n            var dedge_macaron_enabled = true;\n\t\t\t!function(o){function _(n,e){return e.every(function(e){return-1!==n.indexOf(e)})}o.dedge_macaron_is_enabled=function(){return void 0!==o.dedge_macaron_enabled&&o.dedge_macaron_enabled},o.dedge_macaron_get_consent_categories=function(){if(!o.dedge_macaron_is_enabled())return["needed","prefs","stats","ads","unknown"];var e=function(e){e=("; "+document.cookie).split(`; ${e}=`);return 2===e.length?decodeURIComponent(e.pop().split(";").shift()):null}("_deCookiesConsent"),n=[];return n=!1!==e?JSON.parse(e):n},o.dedge_macaron_on_consent=function(e,n,d){d=d||function(){};function o(o,t,e,a){return function(e){var n;r||(o=Array.isArray(o)?o:[o],(n=dedge_macaron_get_consent_categories())&&n.length&&(_(n,o)||_(o,["any"]))?(r=!0,t(n,a,e)):d(n,a,e))}}var t,r=!1;document.addEventListener("_deCookiesConsentGivenVanilla",o(e,n,0,"consentgiven")),t=o(e,n,0,"docready"),/complete|loaded|interactive/.test(document.readyState)?t({detail:"DOMContentAlreadyLoaded"}):document.addEventListener("DOMContentLoaded",function(e){t(e)})},o.dedge_macaron_load_consent_dependent_sections=function(i){var s,e,n;"GIVEN"!==(i=i||"GIVEN")&&"DENIED"!==i||(s="[MacaronCDS("+i+")] ",e=function(){var r="data-macaron-consent-cat";"DENIED"===i&&(r="data-macaron-consent-denied-cat");var c=dedge_macaron_get_consent_categories(),e=jQuery(\'script[type="application/json"][data-macaron-aware="true"][\'+r+"]");0<e.length&&e.each(function(e,n){var o=jQuery(this),t=o.attr(r),a=o.attr("id")||"unknown-"+i+"-"+e,e=(e=t.split(",")).map(function(e){return e.replace(/[^a-z]+/g,"")});if("GIVEN"===i?_(c,e):!_(c,e)){window.console&&console.log(s+"LOAD #"+a+" for "+t);try{var d=JSON.parse(o.text());o.after(d),o.remove()}catch(e){window.console&&console.log(s+"ERROR",e,o,t)}}else window.console&&console.log(s+"SKIP #"+a+". Required="+t+"; Current="+c.join(","))})},"undefined"==typeof jQuery?n=setInterval(function(){"undefined"!=typeof jQuery&&(clearInterval(n),e())},150):e())},o.dedge_macaron_on_consent("any",function(){o.dedge_macaron_load_consent_dependent_sections("GIVEN")}),o.dedge_macaron_on_consent("any",function(){o.dedge_macaron_load_consent_dependent_sections("DENIED")})}(window);        </script>\n        <!-- D-EdgeFBTrackingSupportsGA4 -->\t\t\t<script no-loader>\r\n\t\t\t\tfb_tracking_var = {\r\n\t\t\t\t\tusetracking: \'1\',\r\n\t\t\t\t};\r\n\t\t\t\t\t\t\tfb_tracking_var.urls = [\'book-secure.com\', \'fastbookings.biz\', \'redirect.fastbooking.com\', \'fastbooking.co.uk\'];\r\n\t\t\t\t\t\t\t\tfb_tracking_var.usegtm = \'1\';\r\n\r\n\t\t\t\tfb_tracking_var.tracker = {id_hotel: \'UA-20463713-51\', id_fastbooking_all: \'UA-4717938-7\', id_client: \'UA-1255089-1\', "fb-ga4-dedge-id": "G-48PGB9XQTY", "fb-ga4-dedgeall-id": "G-CMJG3ZE5EE", "fb-ga4-hotel-id": "G-48JDKX4SBH", enable_conversion_linker: \'true\'};dataLayer = [{id_hotel: \'UA-20463713-51\', id_fastbooking_all: \'UA-4717938-7\', id_client: \'UA-1255089-1\', "fb-ga4-dedge-id": "G-48PGB9XQTY", "fb-ga4-dedgeall-id": "G-CMJG3ZE5EE", "fb-ga4-hotel-id": "G-48JDKX4SBH", enable_conversion_linker: \'true\'}];\t\t\t\t\t\tfb_tracking_var.gtmfb = \'GTM-NHJGD93\';\r\n\t\t\t\t\t\t(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\': new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);})(window,documen ...

# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/content_app/lib/python3.10/site-packages/langchain_community/document_loaders/text.py:41, in TextLoader.load(self)
#      40 try:
# ---> 41     with open(self.file_path, encoding=self.encoding) as f:
#      42         text = f.read()
#
# OSError: [Errno 36] File name too long: "\n\n\n\n\n\n \n\n \n\n\n\n\n\n\nOfficial Website | Park Hotel Tokyo | Art Hotel in Tokyo\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nEn|Ja\n\n\n\n\n\n\n\n\nAccess|My Booking \nBook Now\n\n\n\n\n\n\n\n\n\nClose\n\n\n\n\n\n\n\n\n\n\nART at Park Hotel Tokyo\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nART at Park Hotel TokyoART coloursArtist in ResidenceCorridor GalleryArt Exhibitions & Events CalendarTokyo Museum GuideAwards \n\n\n \n\n\nRooms & Suites\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nRooms & SuitesArtist RoomsGuest RoomsSuite RoomAmenities & Rentals \n\n\n \n\n\nSpecial Offers\n\n\n\n\n \n\n\nRestaurants & Bar\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nRestaurants & BarHanasanshouART colours DiningThe SocietyNews Art CaféBlue RoomScarlet RoomBreakfastRoom Service \n\n\n \n\n\nExperience Art at Art Hotel\n\n\n\n\n \n\n\nFacilities & Services\n\n\n\n\n \n\n\nArt Shop / Online\n\n\n\n\n \n\n\nNews & Events\n\n\n\n\n \n\n\nPhotos\n\n\n\n\n \n\n\nSDGs\n\n\n\n\n \n\n\nNewsletter\n\n\n\n\n\n\nAccessMy BookingContact UsFAQ\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n01\n\n\n\n\n\n\n02\n\n\n\n\n\n\n03\n\n\n\n\n\n\nArt Hotel in TokyoWhere Every Stay is a Masterpiece. \n\n\n\n\n\nUnveiling Japan's Artistry in Tokyo's Creative RetreatThe Park Hotel TokyoDiscover an escape into a world where contemporary art and serene hospitality blend seamlessly at Tokyo at Park Hotel Tokyo where a rich tapestry of contemporary Japanese artistry awaits on each floor. We invite you to wander through our collection and witness the unique perspectives of Japanese artisans through art.\n\n\n\n\n\n\nStay Experience\n\n Discover \nAs dusk descends, let the breathtaking cityscape be your backdrop as you unwind with a glass of wine in hand. Your journey of artistic exploration doesn't end at the gallery; it continues in each of our artist rooms, with the vibrant essence of Japan’s unique artists weaving through every stroke on the wall. \n\n Discover \n\n\n\n\nEXECUTIVE MUSEUM LOUNGE\nmore info\n\n\n\n\n\nArtist Rooms\nmore info\n\n\n\n\n\nCorridor Gallery Exhibit\nmore info\n\n\n\n\n\nTable Style Tea Ceremony\nmore info\n\n\n\n\n\nBar The Society\nmore info\n\n\n\n\n\nFine dining\nmore info\n\n\n\n\n\n\n\nAccommodations\n\n Discover \nGuest Rooms & Suites\nPark Hotel Tokyo's rooms and Signature Suites are elevated urban sanctuaries blending a contemporary design with a dynamic view of Rooms the Tokyo city skyline for an unparalleled stay in during your visit to Japan.\n\n Discover \n\n\n\n\nCorner King\n\n\n\n\n\n\nQueen Tokyo Tower Side\n\n\n\n\n\n\nDeluxe King\n\n\n\n\n\n\nDeluxe Triple\n\n\n\n\n\n\nPark Suite\n\n\n\n\n\n\n\n\nNews & Events\n\n Discover \nNews, Art Exhibitions & Information \n Discover\n\n\n\n\n\n\n\nArt\nJanuary 29, 2024\n\n\n\n\t\t\t\t\t\t[Exhibition] CINQ ARTS GALLERY\n\n Read More\n\n\n\n\n\n\nArt\nFebruary 21, 2024\n\n\n\n\t\t\t\t\t\tArtist room created by Mana Osawa\n\n Read More\n\n\n\n\n\n\nArt\nJanuary 27, 2024\n\n\n\n\t\t\t\t\t\t[Exhibition]Enjoy! Aging! Collab! Collab! Collab!\n\n Read More\n\n\n\n\n\n\nArt\nJanuary 23, 2024\n\n\n\n\t\t\t\t\t\tThe 39th artist room “Treasure Box” created by Misa Ohashi is now completed.\n\n Read More\n\n\n\n\n\n\n\n\n\n“Infinite Time and Space Amid Cognizant Japanese Beauty”\n\n\n\nAccessMy Booking\nBook Now\n\n\n\nPress RoomCorporate ContractsTravel Agency EnquiryBlogPrivacy Policy\n\n\n\nPARK HOTEL TOKYO\nShiodome Media Tower 1-7-1 Higashi Shimbashi, Minato-ku 1057227 Tokyo \r\nTel. + 81-3-6252-1111\n\n\nConnect with us\n\xa0\xa0|\xa0\xa0\n\n\n\n\n\n\n\n\n\n\n © 2024 PARK HOTEL TOKYO, SHIODOME\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 4
#       1 from langchain_community.document_loaders import TextLoader
#       3 loader = TextLoader(soup.text)
# ----> 4 loader.load()
#
# File ~/.pyenv/versions/3.10.6/envs/content_app/lib/python3.10/site-packages/langchain_community/document_loaders/text.py:57, in TextLoader.load(self)
#      55         raise RuntimeError(f"Error loading {self.file_path}") from e
#      56 except Exception as e:
# ---> 57     raise RuntimeError(f"Error loading {self.file_path}") from e
#      59 metadata = {"source": self.file_path}
#      60 return [Document(page_content=text, metadata=metadata)]
#
# RuntimeError: Error loading
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Official Website | Park Hotel Tokyo | Art Hotel in Tokyo
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# En|Ja
#
#
#
#
#
#
#
#
# Access|My Booking
# Book Now
#
#
#
#
#
#
#
#
#
# Close
#
#
#
#
#
#
#
#
#
#
# ART at Park Hotel Tokyo
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ART at Park Hotel TokyoART coloursArtist in ResidenceCorridor GalleryArt Exhibitions & Events CalendarTokyo Museum GuideAwards
#
#
#
#
#
# Rooms & Suites
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Rooms & SuitesArtist RoomsGuest RoomsSuite RoomAmenities & Rentals
#
#
#
#
#
# Special Offers
#
#
#
#
#
#
#
# Restaurants & Bar
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Restaurants & BarHanasanshouART colours DiningThe SocietyNews Art CaféBlue RoomScarlet RoomBreakfastRoom Service
#
#
#
#
#
# Experience Art at Art Hotel
#
#
#
#
#
#
#
# Facilities & Services
#
#
#
#
#
#
#
# Art Shop / Online
#
#
#
#
#
#
#
# News & Events
#
#
#
#
#
#
#
# Photos
#
#
#
#
#
#
#
# SDGs
#
#
#
#
#
#
#
# Newsletter
#
#
#
#
#
#
# AccessMy BookingContact UsFAQ
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 01
#
#
#
#
#
#
# 02
#
#
#
#
#
#
# 03
#
#
#
#
#
#
# Art Hotel in TokyoWhere Every Stay is a Masterpiece.
#
#
#
#
#
# Unveiling Japan's Artistry in Tokyo's Creative RetreatThe Park Hotel TokyoDiscover an escape into a world where contemporary art and serene hospitality blend seamlessly at Tokyo at Park Hotel Tokyo where a rich tapestry of contemporary Japanese artistry awaits on each floor. We invite you to wander through our collection and witness the unique perspectives of Japanese artisans through art.
#
#
#
#
#
#
# Stay Experience
#
#  Discover
# As dusk descends, let the breathtaking cityscape be your backdrop as you unwind with a glass of wine in hand. Your journey of artistic exploration doesn't end at the gallery; it continues in each of our artist rooms, with the vibrant essence of Japan’s unique artists weaving through every stroke on the wall.
#
#  Discover
#
#
#
#
# EXECUTIVE MUSEUM LOUNGE
# more info
#
#
#
#
#
# Artist Rooms
# more info
#
#
#
#
#
# Corridor Gallery Exhibit
# more info
#
#
#
#
#
# Table Style Tea Ceremony
# more info
#
#
#
#
#
# Bar The Society
# more info
#
#
#
#
#
# Fine dining
# more info
#
#
#
#
#
#
#
# Accommodations
#
#  Discover
# Guest Rooms & Suites
# Park Hotel Tokyo's rooms and Signature Suites are elevated urban sanctuaries blending a contemporary design with a dynamic view of Rooms the Tokyo city skyline for an unparalleled stay in during your visit to Japan.
#
#  Discover
#
#
#
#
# Corner King
#
#
#
#
#
#
# Queen Tokyo Tower Side
#
#
#
#
#
#
# Deluxe King
#
#
#
#
#
#
# Deluxe Triple
#
#
#
#
#
#
# Park Suite
#
#
#
#
#
#
#
#
# News & Events
#
#  Discover
# News, Art Exhibitions & Information
#  Discover
#
#
#
#
#
#
#
# Art
# January 29, 2024
#
#
#
# 						[Exhibition] CINQ ARTS GALLERY
#
#  Read More
#
#
#
#
#
#
# Art
# February 21, 2024
#
#
#
# 						Artist room created by Mana Osawa
#
#  Read More
#
#
#
#
#
#
# Art
# January 27, 2024
#
#
#
# 						[Exhibition]Enjoy! Aging! Collab! Collab! Collab!
#
#  Read More
#
#
#
#
#
#
# Art
# January 23, 2024
#
#
#
# 						The 39th artist room “Treasure Box” created by Misa Ohashi is now completed.
#
#  Read More
#
#
#
#
#
#
#
#
#
# “Infinite Time and Space Amid Cognizant Japanese Beauty”
#
#
#
# AccessMy Booking
# Book Now
#
#
#
# Press RoomCorporate ContractsTravel Agency EnquiryBlogPrivacy Policy
#
#
#
# PARK HOTEL TOKYO
# Shiodome Media Tower 1-7-1 Higashi Shimbashi, Minato-ku 1057227 Tokyo
# Tel. + 81-3-6252-1111
#
#
# Connect with us
#   |
#
#
#
#
#
#
#
#
#
#
#  © 2024 PARK HOTEL TOKYO, SHIODOME
